# %%
# 1. PyTorch + torchvision (Colab에서 지원되는 안정 버전)
# !pip install torch==2.2.2 torchvision==0.17.2 torchaudio==2.2.2


# 3. 의존성 라이브러리 설치
# !pip install --upgrade basicsr facexlib gfpgan

# 4. OpenCV + numpy (영상 처리용)
# !pip install numpy==1.26.4 opencv-python==4.10.0.84

# 5. tqdm (진행바 표시용)
# !pip install tqdm
# Out:
# ...
#   Using cached torch-2.2.2-cp312-cp312-manylinux1_x86_64.whl.metadata (25 kB)
# ...
#   Using cached torchvision-0.17.2-cp312-cp312-manylinux1_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached torchaudio-2.2.2-cp312-cp312-manylinux1_x86_64.whl.metadata (6.4 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
# 2. Real-ESRGAN 공식 깃허브 설치
# !pip install git+https://github.com/xinntao/Real-ESRGAN.git
# Out:
# ...
#   Cloning https://github.com/xinntao/Real-ESRGAN.git to /tmp/pip-req-build-2cvzk67x
#   Running command git clone --filter=blob:none --quiet https://github.com/xinntao/Real-ESRGAN.git /tmp/pip-req-build-2cvzk67x
#   Resolved https://github.com/xinntao/Real-ESRGAN.git to commit a4abfb2979a7bbff3f69f58f58ae324608821e27
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.4/299.4 kB 27.8 MB/s eta 0:00:00
# ...

# %%
# !mkdir -p weights
# !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -O weights/RealESRGAN_x4plus.pth
# !ls -lh weights
# Out:
# --2025-12-01 06:58:00--  https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# 이부분 지워야함
# from torchvision.transforms.functional_tensor import rgb_to_grayscale

# %%
import os
import cv2
import torch
import numpy as np
from PIL import Image
from tqdm import tqdm

from realesrgan import RealESRGANer
from basicsr.archs.rrdbnet_arch import RRDBNet

# ---------------------------------------
# 모델 로드
# ---------------------------------------
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = RRDBNet(
    num_in_ch=3,
    num_out_ch=3,
    num_feat=64,
    num_block=23,
    num_grow_ch=32,
    scale=4
)

upscaler = RealESRGANer(
    scale=4,
    model_path='weights/RealESRGAN_x4plus.pth',
    model=model,
    tile=0,
    tile_pad=10,
    pre_pad=0,
    half=False,
    device=device
)

# ---------------------------------------
# 단일 영상 파일 처리
# ---------------------------------------
INPUT_VIDEO = "/content/drive/MyDrive/elderlycare_violence/org_video/t_v006_converted.avi"
OUTPUT_VIDEO = "/content/drive/MyDrive/elderlycare_violence/enhanced_video/t_v006_converted_enhanced.mp4"

os.makedirs(os.path.dirname(OUTPUT_VIDEO), exist_ok=True)

cap = cv2.VideoCapture(INPUT_VIDEO)
fps = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

out_width, out_height = width * 4, height * 4

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(OUTPUT_VIDEO, fourcc, fps, (out_width, out_height))

for _ in tqdm(range(frame_count)):
    ret, frame = cap.read()
    if not ret:
        break

    img = frame[:, :, ::-1]  # BGR → RGB

    # RealESRGAN 업스케일
    sr_img, _ = upscaler.enhance(img, outscale=4)

    # RGB → BGR 변환
    sr_frame = sr_img[:, :, ::-1]

    out.write(sr_frame)

cap.release()
out.release()

print("영상 복원 완료")
# Out:
#  60%|█████▉    | 193/322 [30:03<20:14,  9.42s/it]
